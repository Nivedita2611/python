# %%
import pandas as pd
import numpy as np

# %%
def clean_price_data(price):
    if isinstance(price, str):
        price = price.replace(',','').replace('₹','').strip()
    if price.isnumeric():
        return float(price)

# %%
def split_rr_data(rr):
    if isinstance(rr, str):
        rr = rr.split('&')
        return rr[0], rr[1]
    else:
        return np.nan, np.nan

# %%
df['cleaned_price']=df['price'].apply(clean_price_data)

# %%
df['ratings'], df['reviews'] = zip(*df['rr'].apply(split_rr_data)) # Unpacking the tuple

# %%
df
# Out:
#                                                   name      price  \
# 0    Lenovo V15 G2 Core i5 11th Gen - (8 GB/512 GB ...    ₹53,500
# 1    ASUS TUF Gaming F15 Core i5 10th Gen - (8 GB/5...    ₹51,990
# 2    ASUS Vivobook 15 Core i3 11th Gen - (8 GB/512 ...    ₹35,990
# 3    ASUS VivoBook 14 (2021) Celeron Dual Core - (4...    ₹23,990
# 4    RedmiBook Pro Core i5 11th Gen - (8 GB/512 GB ...    ₹38,990
# ..                                                 ...        ...
# 307  ASUS ROG Zephyrus M16 (2022) Core i9 12th Gen ...  ₹2,41,990
# 308  ASUS ROG Strix SCAR 15 (2022) Core i9 12th Gen...  ₹2,81,990
# 309  APPLE MacBook Air M1 - (16 GB/256 GB SSD/Mac O...  ₹1,12,900
# 310  HP Pavilion Gaming Ryzen 5 Quad Core 3550H - (...    ₹56,990
# 311  DELL Ryzen 3 Quad Core 5425U - (8 GB/512 GB SS...    ₹40,990
#
#                               rr  cleaned_price         ratings       reviews
# 0          5 Ratings & 0 Reviews        53500.0      5 Ratings      0 Reviews
# 1    5,563 Ratings & 539 Reviews        51990.0  5,563 Ratings    539 Reviews
# 2       575 Ratings & 56 Reviews        35990.0    575 Ratings     56 Reviews
# 3    1,172 Ratings & 133 Reviews        23990.0  1,172 Ratings    133 Reviews
# 4    4,658 Ratings & 527 Reviews        38990.0  4,658 Ratings    527 Reviews
# ..                           ...            ...             ...           ...
# 307        3 Ratings & 2 Reviews       241990.0      3 Ratings      2 Reviews
# 308        4 Ratings & 0 Reviews       281990.0      4 Ratings      0 Reviews
# 309     774 Ratings & 86 Reviews       112900.0    774 Ratings     86 Reviews
# 310  2,214 Ratings & 249 Reviews        56990.0  2,214 Ratings    249 Reviews
# 311       10 Ratings & 1 Reviews        40990.0     10 Ratings      1 Reviews
#
# [312 rows x 6 columns]
